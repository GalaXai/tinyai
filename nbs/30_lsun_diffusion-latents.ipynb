# %% [markdown]
# # LSUN Bedrooms

# %% [markdown]
# ## Setup

# %%
from tinyai.imports import *
from tinyai.diffusion import *
import shutil
from glob import glob
from fastprogress import progress_bar
from diffusers import AutoencoderKL, UNet2DConditionModel

# %%
import timm

# %%
torch.set_printoptions(precision=4, linewidth=140, sci_mode=False)
torch.manual_seed(1)
mpl.rcParams['image.cmap'] = 'gray_r'
mpl.rcParams['figure.dpi'] = 70

set_seed(42)
if fc.defaults.cpus>8: fc.defaults.cpus=8

# %% [markdown]
# ## Data processing

# %%
path_data = Path('data')
path_data.mkdir(exist_ok=True)
path = path_data/'bedroom'

# %% [markdown]
# 20% datasplit from original dataset,

# %%
url = 'https://s3.amazonaws.com/fast-ai-imageclas/bedroom.tgz'
if not path.exists():
    path_zip = fc.urlsave(url, path_data)
    shutil.unpack_archive('data/bedroom.tgz', 'data')

# %%
bs = 64

# %%
def to_img(f): return read_image(f, mode=ImageReadMode.RGB)/255

# %%
class ImagesDS:
    def __init__(self, spec):
        self.path = Path(path)
        self.files = glob(str(spec), recursive=True)
    def __len__(self): return len(self.files)
    def __getitem__(self, i): return to_img(self.files[i])[:, :256,:256]

# %%
ds = ImagesDS(path/f'**/*.jpg')

# %%
dl = DataLoader(ds, batch_size=bs, num_workers=fc.defaults.cpus)
xb = next(iter(dl))
show_images(xb[:16], imsize=2)

# %%
xb[:16].shape
# Out:
# torch.Size([16, 3, 256, 256])

# %%
16*3*256*256
# Out:
# 3145728

# %% [markdown]
# ## VAE

# %%
vae = AutoencoderKL.from_pretrained("stabilityai/sd-vae-ft-ema").cuda().requires_grad_(False)
# Out:
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]

# %%
xe = vae.encode(xb.cuda())

# %%
xs = xe.latent_dist.mean[:16]
xs.shape
# Out:
# torch.Size([16, 4, 32, 32])

# %%
(16*3*256*256)/(16*4*32*32)
# Out:
# 48.0

# %% [markdown]
# It's 48x data reduction, but the image is reduced by factor of 8. the number of pixels on the image is decreased by $8^2$
#
# Latent Visualization

# %%
show_images(((xs[:16,:3])/4).sigmoid(), imsize=2)

# %%
xd = to_cpu(vae.decode(xs))
show_images(xd['sample'].clamp(0,1), imsize=2)

# %% [markdown]
# We don't want to encode the images to latents every epoch, so we do it once and save the memory map to disk, that we later load so it's faster.

# %%
mmpath = Path('data/bedroom/data.npmm')

# %%
len(ds)
# Out:
# 303125

# %%
mmshape = (303125,4,32,32)

# %%
if not mmpath.exists():
    a = np.memmap(mmpath, np.float32, mode='w+', shape=mmshape)
    i = 0
    for b in progress_bar(dl):
        n = len(b)
        a[i:i+n] = to_cpu(vae.encode(b.cuda()).latent_dist.mean).numpy()
        i += n
    a.flush()
    del(a)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4737' class='' max='4737' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4737/4737 47:58&lt;00:00]
#     </div>

# %%
lats = np.memmap(mmpath, dtype=np.float32, mode='r', shape=mmshape)

# %%
b = torch.tensor(lats[:16])

# %%
xd = to_cpu(vae.decode(b.cuda()))
show_images(xd['sample'].clamp(0,1), imsize=2)

# %% [markdown]
# ## Noisify

# %%
def collate_ddpm(b): return noisify(default_collate(b)*0.2)

# %%
n = len(lats)

# %% [markdown]
# 90% train valid split

# %%
tds = lats[:n//10*9 ]
vds = lats[ n//10*9:]

# %%
bs = 128

# %%
dls = DataLoaders(*get_dls(tds, vds, bs=bs, num_workers=fc.defaults.cpus, collate_fn=collate_ddpm))

# %%
import warnings

# %%
warnings.simplefilter('ignore', UserWarning)

# %%
(xt,t),eps = b = next(iter(dls.train))

# %%
show_images(xt[:9,0], imsize=1.5)

# %% [markdown]
# Decoded noisified images.

# %%
xte = vae.decode(xt[:9].cuda()*5)['sample']
show_images(xte.clamp(0,1), imsize=1.5)

# %% [markdown]
# ## Train

# %%
def init_ddpm(model):
    for o in model.downs:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

    for o in model.ups:
        for p in o.resnets: p.conv2[-1].weight.data.zero_()

# %%
lr = 3e-3
epochs = 25
opt_func = partial(optim.AdamW, eps=1e-5)
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
cbs = [DeviceCB(), ProgressCB(plot=True), MetricsCB(), BatchSchedCB(sched), MixedPrecision()]
model = EmbUNetModel(in_channels=4, out_channels=4, nfs=(128, 256, 512, 768), num_layers=2,
                     attn_start=1, attn_chans=16)
init_ddpm(model)
learn = Learner(model, dls, nn.MSELoss(), lr=lr, cbs=cbs, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.296</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.278</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.271</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.269</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.265</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.264</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.261</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.263</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.258</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.256</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.256</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.254</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.256</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.254</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.254</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.255</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.253</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.255</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.252</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.253</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.251</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.254</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.251</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.249</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.250</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.252</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.249</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.250</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.247</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.248</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.247</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.250</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.247</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.246</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.246</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.244</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.245</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.245</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.245</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.244</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.242</td>
#       <td>20</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.242</td>
#       <td>20</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.243</td>
#       <td>21</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.243</td>
#       <td>21</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.242</td>
#       <td>22</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.243</td>
#       <td>22</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.243</td>
#       <td>23</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.244</td>
#       <td>23</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.241</td>
#       <td>24</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.243</td>
#       <td>24</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
torch.save(learn.model.state_dict(), 'models/lsun_diffusion-latents.pkl')

# %% [markdown]
# ## Sampling

# %%
sz = (16,4,32,32)

# %%
# set_seed(42)
preds = sample(ddim_step, model, sz, steps=100, eta=1., clamp=False)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:02<00:00]
#     </div>

# %%
s = preds[-1]*5

# %%
with torch.no_grad(): pd = to_cpu(vae.decode(s.cuda()))

# %%
show_images(pd['sample'][:9].clamp(0,1), imsize=5)
